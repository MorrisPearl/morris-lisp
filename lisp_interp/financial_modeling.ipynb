# %%
()

# %%
(load 'mortgage_amortization_example.lsp)
# Out:
#     market_rate rate_incentive coll_interest  ...   bal_c prin_z   bal_z
# 0          5.84           0.00             0  ...  25,000      0  25,000
# 1          5.84           0.16           500  ...  25,000      0  25,125
# 2          5.89           0.11           499  ...  25,000      0  25,251
# 3          5.93           0.07           498  ...  25,000      0  25,377
# 4          5.97           0.03           497  ...  25,000      0  25,504
# ..          ...            ...           ...  ...     ...    ...     ...
# 356        5.92           0.08             0  ...       0      0       0
# 357        5.92           0.08             0  ...       0      0       0
# 358        5.92           0.08             0  ...       0      0       0
# 359        5.92           0.08             0  ...       0      0       0
# 360        5.92           0.08             0  ...       0      0       0
#
# [361 rows x 21 columns]
# Wrote mortgage_amortization_example.csv

# %%
(load 'sofr_monte_carlo_example.lsp)
# Out:
# Calibrating against 48 options...
# a=2.27809  theta_bar=0.042102707222271475  sigma1=1e-06  sigma2=0.01337  total squared pricing error=0.187137087497292
# Wrote sofr_monte_carlo_example.csv (years + 20 simulated mortgage-rate paths)

# %%
(load 'sofr_floating_rate_example.lsp)
# Out:
# SOFR forward curve, first 12 months:
#       month sofr_1m
# 0    1.0000  0.0409
# 1    2.0000  0.0414
# 2    3.0000  0.0418
# 3    4.0000  0.0422
# 4    5.0000  0.0422
# 5    6.0000  0.0422
# 6    7.0000  0.0428
# 7    8.0000  0.0428
# 8    9.0000  0.0428
# 9   10.0000  0.0427
# 10  11.0000  0.0427
# 11  12.0000  0.0427
#    sofr_1m coupon_rate  balance interest
# 0   0.0409      0.0559  100,000        0
# 1   0.0409      0.0559  100,000      466
# 2   0.0414      0.0564  100,000      470
# 3   0.0418      0.0568  100,000      473
# 4   0.0422      0.0572  100,000      477
# ..     ...         ...      ...      ...
# 56  0.0417      0.0567  100,000      473
# 57  0.0417      0.0567  100,000      473
# 58  0.0417      0.0567  100,000      473
# 59  0.0417      0.0567  100,000      473
# 60  0.0417      0.0567  100,000      473
#
# [61 rows x 4 columns]
# Wrote sofr_floating_rate_example.csv

# %%
'(1 2 3)
# Out:
# (1 2 3)

# %%
(define letters '(a b c d e))
# Out:
# letters

# %%
letters
# Out:
# (a b c d e)

# %%
(not 4)
# Out:
# #f

# %%
(not #f)
# Out:
# #t

# %%
(while (not (null? (cdr letters)))
       (begin
        (print (car letters))
        (set! letters (cdr letters))
        )
       )
# Out:
# a
# b
# c
# d

# %%
letters
# Out:
# (e)

# %%
(define letters '(a b c d e))
# Out:
# letters

# %%
letters
# Out:
# (a b c d e)

# %%
(define numbers '(1 2 3 4 5))
# Out:
# numbers

# %%
(while (not (null? (cdr letters)))
       (while (not (null? (cdr numbers)))
       (begin
        (print (cons (car letters) (car numbers)))
        (set! letters (cdr letters))
        (set! numbers (cdr numbers))
        )
        )
       )
# Out:
# (a . 1)
# (b . 2)
# (c . 3)
# (d . 4)

# %%
(while (not (null? (cdr letters)))
       (begin
       (while (not (null? (cdr numbers)))
       (begin
        (print (cons (car letters) (car numbers)))
        (set! numbers (cdr numbers))
        )
        (set! letters (cdr letters))
        )
        )
       )
